# %%
import pandas as pd

# Import movies_metadata.csv
movies_metadata = pd.read_csv('movies_metadata.csv')

# Check out the first few rows of the keywords dataset
movies_metadata.head()
# Out:
# C:\Users\alvin\AppData\Local\Temp\ipykernel_15368\165412582.py:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies_metadata = pd.read_csv('movies_metadata.csv')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %% [markdown]
# Each row gives us data (we will highlight some of the important ones here below):
# - Adult. If the movie is for adults.
# - Collections it belongs to. This would be stuff like the Toy Story series and so on.
# - Budget. The amount budgeted for a movie, if it can be found. If data is not available, it is 0.
# - Generes. There's an id for the genre, along with the genre title.
# - id: id within the movies dataset
# - imdb_id: id with IMDB
# - Original Language: Language the movie was produced in
# - Title: Name for the movie
# - Overview: Synopsis of the movie
# - Release Date: Date of release for the movie
# - Revenue: How much revenue the movie made
# - Runtime: How long the movie is
# - Vote Count: Number of votes total cast for this movie
# - Vote Average: Average score of votes
#
# This data should prove to be useful in recommending movies. For example, a user may be predisposed to only want to see movies in a certain language, with a more recent release date, and high budget. We can take some of these factors in our rankings of movies and then recommend them to the user.

# %%
# Import links_small.csv
links_small = pd.read_csv('links_small.csv')

# Check out the first few rows of the keywords dataset
links_small.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %% [markdown]
# This data helps to connect the ids used by the dataset creator and ids used by 3rd parties (such as imdb).

# %%
# Import ratings.csv
ratings = pd.read_csv('ratings_small.csv')

# Check out the first few rows of the keywords dataset
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %% [markdown]
# This dataframe should give us each individual rating for users. We could use this data in conjunction with the links dataframe to grab imdbIds for movies, but more importantly, we could calculate ratings for movies. Although this data seems to be present in the movies_metadata dataframe, it is only provided as an aggregate number there. If we wanted to only get recent reviews, or do incorporate the timestamp of reviews somehow, we could use this dataframe instead.

# %%
# Import keywords.csv
keywords = pd.read_csv('keywords.csv')

# Check out the first few rows of the keywords dataset
keywords.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %% [markdown]
# This dataframe has an id (presumably the movieId), and connects it to a dictionary of keywords for that movie. When gathering results for recommendation, we can try and use these in conjunction with a query from the user to give movies a ranking.
